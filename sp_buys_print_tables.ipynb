# %%
# set up working directory
import os
os.chdir('/Users/michaelboles/Michael/Coding/2020/Insight/Project/Stocks/') 

# load packages
# import warnings; warnings.simplefilter('ignore')
import pandas as pd

# %%
sp_buys_0 = pd.read_csv('./data/1 - buy tables/buy_table_dip=0.csv')

# %%
sp_buys[20215:20225][['date', 'close', 'off from high', 'buy', 'shares bought', 'shares owned', 'cash balance', 'market value']].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_905292ca_952f_11ea_beef_acde48001122" ><thead>    <tr>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >close</th>        <th class="col_heading level0 col2" >off from high</th>        <th class="col_heading level0 col3" >buy</th>        <th class="col_heading level0 col4" >shares bought</th>        <th class="col_heading level0 col5" >shares owned</th>        <th class="col_heading level0 col6" >cash balance</th>        <th class="col_heading level0 col7" >market value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_905292ca_952f_11ea_beef_acde48001122row0_col0" class="data row0 col0" >2008-07-07</td>
#                         <td id="T_905292ca_952f_11ea_beef_acde48001122row0_col1" class="data row0 col1" >1252.31</td>
#                         <td id="T_905292ca_952f_11ea_beef_acde48001122row0_col2" class="data row0 col2" >-19.99</td>
# ...

# %%
sp_buys_20 = pd.read_csv('./data/1 - buy tables/buy_table_dip=-20.csv')

sp_buys_20[20215:20225][['date', 'close', 'off from high', 'buy', 'shares bought', 'shares owned', 'cash balance', 'market value']].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ad2d42be_952f_11ea_beef_acde48001122" ><thead>    <tr>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >close</th>        <th class="col_heading level0 col2" >off from high</th>        <th class="col_heading level0 col3" >buy</th>        <th class="col_heading level0 col4" >shares bought</th>        <th class="col_heading level0 col5" >shares owned</th>        <th class="col_heading level0 col6" >cash balance</th>        <th class="col_heading level0 col7" >market value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ad2d42be_952f_11ea_beef_acde48001122row0_col0" class="data row0 col0" >2008-07-07</td>
#                         <td id="T_ad2d42be_952f_11ea_beef_acde48001122row0_col1" class="data row0 col1" >1252.31</td>
#                         <td id="T_ad2d42be_952f_11ea_beef_acde48001122row0_col2" class="data row0 col2" >-19.99</td>
# ...

# %%
return_summary = pd.read_csv('./data/5 - returns across time intervals/return_summary.csv')
return_summary.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_77136edc_9544_11ea_8fec_acde48001122" ><thead>    <tr>        <th class="col_heading level0 col0" > </th>        <th class="col_heading level0 col1" >One year</th>        <th class="col_heading level0 col2" >Ten years</th>        <th class="col_heading level0 col3" >Thirty years</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_77136edc_9544_11ea_8fec_acde48001122row0_col0" class="data row0 col0" >Mean</td>
#                         <td id="T_77136edc_9544_11ea_8fec_acde48001122row0_col1" class="data row0 col1" >7.69</td>
#                         <td id="T_77136edc_9544_11ea_8fec_acde48001122row0_col2" class="data row0 col2" >6.35</td>
#                         <td id="T_77136edc_9544_11ea_8fec_acde48001122row0_col3" class="data row0 col3" >7.03</td>
#             </tr>
#             <tr>
# ...
